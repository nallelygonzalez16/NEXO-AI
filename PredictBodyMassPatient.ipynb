# %% [markdown]
# <a href="https://colab.research.google.com/github/nallelygonzalez16/NEXO-AI/blob/models/PredictBodyMassPatient.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Análisis del Problema

# %% [markdown]
# ## Entendimiento de los Datos

# %% [markdown]
# ## Exploración de los Datos

# %% [markdown]
# ## Modelo de Machine Learning

# %% [markdown]
# ## Evaluación

# %% [markdown]
# ## Conclusión
